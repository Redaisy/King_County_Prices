# %%
import pandas as pd
df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0         NaN   0.0     ...          7        1180
# 1      7242     2.0         0.0   0.0     ...          7        2170
# 2     10000     1.0         0.0   0.0     ...          6         770
# 3      5000     1.0         0.0   0.0     ...          7        1050
# 4      8080     1.0         0.0   0.0     ...          8        1680
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
from sklearn.model_selection import train_test_split
y = pd.DataFrame()
y['price'] = df['price']
x = df.drop(['price'], axis = 1)
df1, df2, df3, df4 = train_test_split(x, y, test_size = 0.99, random_state = 0)

# %%
df1['Price'] = df['price']
df1.head()
# Out:
# C:\Users\leaf2\Anaconda3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                id        date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 4403   5468730110    5/8/2014         4       2.50         1810      6509
# 10903  1920079062  12/22/2014         5       1.50         2420     43560
# 1241   1796100140   7/15/2014         3       1.50         1350     81549
# 20435  1853080850    6/6/2014         5       2.75         3030      7679
# 8962   6743700015   1/28/2015         3       2.00         1080     11856
#
#        floors  waterfront  view  condition    ...     sqft_above  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize = (10,8))
sns.regplot(df1.sqft_living, df1.Price)
plt.title('Square Feet vs. Housing Price', fontsize = 20)
plt.show()
# Out:
# C:\Users\leaf2\Anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize = (10,8))
sns.regplot(df1.sqft_living, df1.Price, data = df1, color = 'r')
plt.title('Square Feet vs. Housing Price', fontsize = 20)
plt.show()
# Out:
# C:\Users\leaf2\Anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize = (10,8))
sns.regplot(df1.sqft_living, df1.Price, data = df1, scatter_kws = {'color': 'purple', 'alpha': 0.3}, line_kws = {'color': '#CCCC00', 'alpha': 0.3, 'lw':6})
plt.title('Square Feet vs. Housing Price', fontsize = 20)
plt.show()
# Out:
# C:\Users\leaf2\Anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#sns.set()
sns.set_style('whitegrid')
#sns.despine(right = True)

plt.figure(figsize = (10,8))
sns.regplot(df1.sqft_living, df1.Price, data = df1, scatter_kws = {'color': 'purple', 'alpha': 0.3}, line_kws = {'color': '#CCCC00', 'alpha': 0.3, 'lw':6})
plt.title('Square Feet vs. Housing Price', fontsize = 20)
plt.show()
# Out:
# C:\Users\leaf2\Anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize = (10,8))
sns.regplot(df1.sqft_living, df1.Price, data = df1, scatter_kws = {'color': 'purple', 'alpha': 0.3}, line_kws = {'color': '#CCCC00', 'alpha': 0.3, 'lw':6})
plt.title('Square Feet vs. Housing Price', fontsize = 20)
plt.show()
# Out:
# C:\Users\leaf2\Anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0         NaN   0.0     ...          7        1180
# 1      7242     2.0         0.0   0.0     ...          7        2170
# 2     10000     1.0         0.0   0.0     ...          6         770
# 3      5000     1.0         0.0   0.0     ...          7        1050
# 4      8080     1.0         0.0   0.0     ...          8        1680
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
#Preparation to plot regplot between sqft_living and price, which will visualize regression line and confidence interval
#separate dataframe into separate dataframes, one for each grade
#use loc to separate by grade = ?
grade_dfs = []
grades = list(df.grade.value_counts().index)
grades.sort()
for num in grades:
    name_of_df = 'df_'+str(num) 
    name_of_df = df.loc[df['grade'] == num]
    grade_dfs.append(name_of_df)
    
#grade_dfs is list which holds a dataframe for each grade
#Plotting regplot between sqft_living and price for each grade by iterating through grade_dfs

sns.set(style="whitegrid")

for i in range(0 , len(grade_dfs)):
    f, axs = plt.subplots(figsize = (8,6))
    sns.regplot(x='sqft_living', y="price", data=grade_dfs[i], scatter_kws={"color": "green", 'alpha': 0.3}, line_kws={"color": "red"})
    plt.title('Square Feet vs. Price for Houses of Grade ' +str(i+3), fontsize = 15)
    plt.show()
# Out:
# C:\Users\leaf2\Anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Code that was erased from final project:

#convert yr_built to datetime data type
import datetime as dt
#df['yr_built'] = pd.to_datetime(df['yr_built'], format='%Y')
#df.head()


#IGNORE BELOW
#create new time_since variables
#create timestamp column of current time - will update whenever code is rerun
#scrub_df['timestamp'] = dt.datetime.now()

##creating two new variables with unit of days since ____
#scrub_df['since_sold'] = (scrub_df.timestamp - scrub_df.date).dt.days
#scrub_df['since_built'] = (scrub_df.timestamp - scrub_df.yr_built).dt.days
#
#scrub_df.drop(['date','yr_built', 'timestamp'], axis = 1, inplace = True)


r_list = []
adj_r_list = [] 
list_n = list(range(8,11,1)) 
for n in list_n: 
    select_n = RFE(linreg, n_features_to_select = n) 
    select_n = select_n.fit(pre_df, np.ravel(y))   
    selected_columns = pre_df.columns[select_n.support_ ]  
    linreg.fit(pre_df[selected_columns],y) 
    yhat = linreg.predict(pre_df[selected_columns]) 
    SS_Residual = np.sum((y-yhat)**2) 
    SS_Total = np.sum((y-np.mean(y))**2) 
    r_squared = 1 - (float(SS_Residual))/SS_Total 
    print('R-squared:', r_squared) 
    adjusted_r_squared = 1 - (1-r_squared)*(len(y)-1)/(len(y)-pre_df.shape[1]-1) 
    print('Adjusted R-squared:', adjusted_r_squared, '\n') 

    r_list.append(r_squared) 
    adj_r_list.append(adjusted_r_squared)
print(list_n)

select_some = RFE(linreg, n_features_to_select = 10)
select_some = select_some.fit(pre_df, np.ravel(y))
selected_columns = pre_df.columns[select_some.support_]

cv_10_results = cross_val_score(linreg, pre_df[selected_columns], y, cv=10, scoring="neg_mean_squared_error")

cv_10_results

list(zip(select_some.support_, list(pre_df.columns)))
